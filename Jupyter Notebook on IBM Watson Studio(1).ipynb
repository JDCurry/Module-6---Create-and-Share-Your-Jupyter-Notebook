# %%
# Create markdown cell with the title of the notebook
print("JDC EDX Data Science Tools Final Project")
# Out:
# JDC EDX Data Science Tools Final Project

# %%
# Create markdown cell for an introduction
print("This notebook explores various data science concepts and tools.")
# Out:
# This notebook explores various data science concepts and tools.

# %%
# Create markdown cell for an introduction
print("In this notebook we will go over some popular data science tools and libraries")
# Out:
# In this notebook we will go over some popular data science tools and libraries

# %%
# Create markdown cell to list data science languages
print("Data Science Languages")
print("Python")
print("R")
print("Julia")
# Out:
# Data Science Languages
# Python
# R
# Julia

# %%
# Create markdown cell to list data science libraries
print("Data Science Libraries")
print("Pandas")
print("NumPy")
print("Scikit-learn")
# Out:
# Data Science Libraries
# Pandas
# NumPy
# Scikit-learn

# %%
# Create markdown cell with a table of Data Science tools
from IPython.display import Markdown, display

data_science_tools = [
    ["Tool", "Description"],
    ["Python", "A general-purpose programming language used for data analysis, machine learning, and scientific computing"],
    ["R", "A programming language and software environment for statistical computing and graphics"],
    ["SQL", "A domain-specific language used in programming and designed for managing data held in a relational database management system"],
    ["Tableau", "A data visualization and business intelligence tool used to analyze and share insights"],
    ["Pandas", "A library for data manipulation and analysis"],
    ["NumPy", "A library for numerical computing in Python"],
    ["SciPy", "A library for scientific computing in Python"],
    ["Scikit-learn", "A machine learning library for Python"],
    ["TensorFlow", "An open-source machine learning library developed by Google"],
    ["PyTorch", "An open source machine learning library developed by Facebook"],
]

def create_markdown_table(data):
    output = "|"
    for header in data[0]:
        output += f"{header}|"
    output += "\n|"
    for _ in range(len(data[0])):
        output += "---|"
    for row in data[1:]:
        output += "\n|"
        for item in row:
            output += f"{item}|"
    return output

display(Markdown(create_markdown_table(data_science_tools)))
# Out:
# |Tool|Description|
# |---|---|
# |Python|A general-purpose programming language used for data analysis, machine learning, and scientific computing|
# |R|A programming language and software environment for statistical computing and graphics|
# |SQL|A domain-specific language used in programming and designed for managing data held in a relational database management system|
# |Tableau|A data visualization and business intelligence tool used to analyze and share insights|
# |Pandas|A library for data manipulation and analysis|
# |NumPy|A library for numerical computing in Python|
# |SciPy|A library for scientific computing in Python|
# |Scikit-learn|A machine learning library for Python|
# |TensorFlow|An open-source machine learning library developed by Google|
# |PyTorch|An open source machine learning library developed by Facebook|

# %%
# Create markdown cell introducing arithmetic expression examples

print(5+9)
print (5-5)
print (81 / 3)
# Out:
# Here are some examples of arithmetic expressions:
# 14
# 0
# 27.0

# %% [markdown]
# print(5*5)
# print(10*10+50)

# %%
# Create code cell to convert minutes to hours

minutes = 150
hours = minutes / 60

print(f"{minutes} minutes is equal to {hours:.2f} hours")
# Out:
# 150 minutes is equal to 2.50 hours

# %%
# Insert markdown cell to list objectives
print("Objectives")
print("Learn about data preprocessing techniques.")
print("Explore machine learning algorithms.")
print("Visualize data using Python libraries.")
# Out:
# Objectives
# Learn about data preprocessing techniques.
# Explore machine learning algorithms.
# Visualize data using Python libraries.

# %%
# Create markdown cell to indicate the Author’s name
print("This notebook was created by Josh Curry.")
# Out:
# This notebook was created by Josh Curry.
